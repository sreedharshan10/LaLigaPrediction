# %%
import pandas as pd

# %%
matches=pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga
# 0  2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1  2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W  2.0  1.0
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt
# 0  Athletic Club  ...  Match Report    NaN  14.0   8.0  16.0  2.0  0     0  \
# 1        Almería  ...  Match Report    NaN  25.0   9.0  17.0  1.0  0     0
# 2     Celta Vigo  ...  Match Report    NaN   9.0   2.0  19.4  0.0  0     1
# 3         Getafe  ...  Match Report    NaN  26.0  12.0  17.7  0.0  0     0
# 4  Real Sociedad  ...  Match Report    NaN  17.0   8.0  15.9  1.0  0     0
#
#    season         team
# 0    2023  Real Madrid
# 1    2023  Real Madrid
# 2    2023  Real Madrid
# 3    2023  Real Madrid
# 4    2023  Real Madrid
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1618, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Real Madrid        81
# Cadiz              81
# Celta Vigo         81
# Mallorca           81
# Barcelona          81
# Osasuna            81
# Real Sociedad      81
# Real Betis         81
# Villarreal         81
# Getafe             81
# Rayo Vallecano     81
# Valencia           81
# Athletic Club      81
# Atletico Madrid    80
# Sevilla            80
# Espanyol           76
# Elche              76
# Alaves             43
# Girona             43
# Granada            43
# Almeria            43
# Valladolid         38
# Levante            38
# Las Palmas          5
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches["date"]=pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"]= matches["venue"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W  2.0  1.0
# 36 2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0.0  4.0
# 37 2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W  2.0  1.0
# 38 2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  1.0  3.0
# 39 2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0.0  1.0
#
#          opponent  ...  notes    sh   sot  dist   fk pk pkatt season
# 0   Athletic Club  ...    NaN  14.0   8.0  16.0  2.0  0     0   2023  \
# 1         Almería  ...    NaN  25.0   9.0  17.0  1.0  0     0   2023
# 2      Celta Vigo  ...    NaN   9.0   2.0  19.4  0.0  0     1   2023
# 3          Getafe  ...    NaN  26.0  12.0  17.7  0.0  0     0   2023
# 4   Real Sociedad  ...    NaN  17.0   8.0  15.9  1.0  0     0   2023
# ..            ...  ...    ...   ...   ...   ...  ... ..   ...    ...
# 35     Villarreal  ...    NaN  11.0   4.0  14.8  0.0  0     0   2021
# 36     Celta Vigo  ...    NaN   3.0   1.0  19.5  0.0  0     0   2021
# 37       Espanyol  ...    NaN  27.0   9.0  16.9  2.0  0     0   2021
# 38        Levante  ...    NaN   6.0   2.0  20.2  1.0  0     0   2021
# 39          Cádiz  ...    NaN   9.0   2.0  19.0  2.0  0     0   2021
#
#            team  venue_code
# 0   Real Madrid           0
# 1   Real Madrid           0
# 2   Real Madrid           0
# 3   Real Madrid           1
# 4   Real Madrid           1
# ..          ...         ...
# 35       Alaves           1
# 36       Alaves           0
# 37       Alaves           1
# 38       Alaves           0
# 39       Alaves           1
#
# [1618 rows x 28 columns]

# %%
matches["opp_code"]=matches["opponent"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W  2.0  1.0
# 36 2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0.0  4.0
# 37 2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W  2.0  1.0
# 38 2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  1.0  3.0
# 39 2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0.0  1.0
#
#          opponent  ...    sh   sot  dist   fk pk pkatt season         team
# 0   Athletic Club  ...  14.0   8.0  16.0  2.0  0     0   2023  Real Madrid  \
# 1         Almería  ...  25.0   9.0  17.0  1.0  0     0   2023  Real Madrid
# 2      Celta Vigo  ...   9.0   2.0  19.4  0.0  0     1   2023  Real Madrid
# 3          Getafe  ...  26.0  12.0  17.7  0.0  0     0   2023  Real Madrid
# 4   Real Sociedad  ...  17.0   8.0  15.9  1.0  0     0   2023  Real Madrid
# ..            ...  ...   ...   ...   ...  ... ..   ...    ...          ...
# 35     Villarreal  ...  11.0   4.0  14.8  0.0  0     0   2021       Alaves
# 36     Celta Vigo  ...   3.0   1.0  19.5  0.0  0     0   2021       Alaves
# 37       Espanyol  ...  27.0   9.0  16.9  2.0  0     0   2021       Alaves
# 38        Levante  ...   6.0   2.0  20.2  1.0  0     0   2021       Alaves
# 39          Cádiz  ...   9.0   2.0  19.0  2.0  0     0   2021       Alaves
#
#     venue_code  opp_code
# 0            0         2
# 1            0         1
# 2            0         6
# 3            1        10
# 4            1        19
# ..         ...       ...
# 35           1        23
# 36           0         6
# 37           1         9
# 38           0        14
# 39           1         7
#
# [1618 rows x 29 columns]

# %%
matches["hour"]=matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W  2.0  1.0
# 36 2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0.0  4.0
# 37 2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W  2.0  1.0
# 38 2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  1.0  3.0
# 39 2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0.0  1.0
#
#          opponent  ...   sot  dist   fk  pk pkatt season         team
# 0   Athletic Club  ...   8.0  16.0  2.0   0     0   2023  Real Madrid  \
# 1         Almería  ...   9.0  17.0  1.0   0     0   2023  Real Madrid
# 2      Celta Vigo  ...   2.0  19.4  0.0   0     1   2023  Real Madrid
# 3          Getafe  ...  12.0  17.7  0.0   0     0   2023  Real Madrid
# 4   Real Sociedad  ...   8.0  15.9  1.0   0     0   2023  Real Madrid
# ..            ...  ...   ...   ...  ...  ..   ...    ...          ...
# 35     Villarreal  ...   4.0  14.8  0.0   0     0   2021       Alaves
# 36     Celta Vigo  ...   1.0  19.5  0.0   0     0   2021       Alaves
# 37       Espanyol  ...   9.0  16.9  2.0   0     0   2021       Alaves
# 38        Levante  ...   2.0  20.2  1.0   0     0   2021       Alaves
# 39          Cádiz  ...   2.0  19.0  2.0   0     0   2021       Alaves
#
#    venue_code  opp_code  hour
# 0           0         2    21
# 1           0         1    19
# 2           0         6    21
# 3           1        10    16
# 4           1        19    21
# ..        ...       ...   ...
# 35          1        23    14
# 36          0         6    18
# 37          1         9    19
# 38          0        14    19
# 39          1         7    20
#
# [1618 rows x 30 columns]

# %%
matches["day_code"]=matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W  2.0  1.0
# 36 2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0.0  4.0
# 37 2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W  2.0  1.0
# 38 2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  1.0  3.0
# 39 2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0.0  1.0
#
#          opponent  ...  dist   fk  pk  pkatt season         team venue_code
# 0   Athletic Club  ...  16.0  2.0   0      0   2023  Real Madrid          0  \
# 1         Almería  ...  17.0  1.0   0      0   2023  Real Madrid          0
# 2      Celta Vigo  ...  19.4  0.0   0      1   2023  Real Madrid          0
# 3          Getafe  ...  17.7  0.0   0      0   2023  Real Madrid          1
# 4   Real Sociedad  ...  15.9  1.0   0      0   2023  Real Madrid          1
# ..            ...  ...   ...  ...  ..    ...    ...          ...        ...
# 35     Villarreal  ...  14.8  0.0   0      0   2021       Alaves          1
# 36     Celta Vigo  ...  19.5  0.0   0      0   2021       Alaves          0
# 37       Espanyol  ...  16.9  2.0   0      0   2021       Alaves          1
# 38        Levante  ...  20.2  1.0   0      0   2021       Alaves          0
# 39          Cádiz  ...  19.0  2.0   0      0   2021       Alaves          1
#
#    opp_code  hour  day_code
# 0         2    21         5
# 1         1    19         5
# 2         6    21         4
# 3        10    16         5
# 4        19    21         6
# ..      ...   ...       ...
# 35       23    14         5
# 36        6    18         5
# 37        9    19         2
# 38       14    19         6
# 39        7    20         6
#
# [1618 rows x 31 columns]

# %%
matches["target"]=(matches["result"]=="W").astype("int")

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W  2.0  1.0
# 36 2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L  0.0  4.0
# 37 2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W  2.0  1.0
# 38 2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L  1.0  3.0
# 39 2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L  0.0  1.0
#
#          opponent  ...   fk  pk  pkatt  season         team venue_code
# 0   Athletic Club  ...  2.0   0      0    2023  Real Madrid          0  \
# 1         Almería  ...  1.0   0      0    2023  Real Madrid          0
# 2      Celta Vigo  ...  0.0   0      1    2023  Real Madrid          0
# 3          Getafe  ...  0.0   0      0    2023  Real Madrid          1
# 4   Real Sociedad  ...  1.0   0      0    2023  Real Madrid          1
# ..            ...  ...  ...  ..    ...     ...          ...        ...
# 35     Villarreal  ...  0.0   0      0    2021       Alaves          1
# 36     Celta Vigo  ...  0.0   0      0    2021       Alaves          0
# 37       Espanyol  ...  2.0   0      0    2021       Alaves          1
# 38        Levante  ...  1.0   0      0    2021       Alaves          0
# 39          Cádiz  ...  2.0   0      0    2021       Alaves          1
#
#    opp_code hour  day_code  target
# 0         2   21         5       1
# 1         1   19         5       1
# 2         6   21         4       1
# 3        10   16         5       1
# 4        19   21         6       1
# ..      ...  ...       ...     ...
# 35       23   14         5       1
# 36        6   18         5       0
# 37        9   19         2       1
# 38       14   19         6       0
# 39        7   20         6       0
#
# [1618 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train=matches[matches["date"]<'2023-01-01']

# %%
test=matches[matches["date"]>'2023-01-01']

# %%
predictors=["venue_code","opp_code","hour","day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds=rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(test["target"],preds)

# %%
acc
# Out:
# 0.6111111111111112

# %%
combined=pd.DataFrame(dict(actual=test["target"],prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           274  64
# 1           153  67

# %%
from sklearn.metrics import precision_score as ps

# %%
ps(test["target"],preds)
# Out:
# 0.5114503816793893

# %%
grouped_matches=matches.groupby("team")

# %%
group=grouped_matches.get_group("Barcelona")

# %%
group
# Out:
#          date   time     comp         round  day venue result   gf   ga
# 0  2023-08-13  21:30  La Liga   Matchweek 1  Sun  Away      D  0.0  0.0  \
# 1  2023-08-20  19:30  La Liga   Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2023-08-27  17:30  La Liga   Matchweek 3  Sun  Away      W  4.0  3.0
# 3  2023-09-03  21:00  La Liga   Matchweek 4  Sun  Away      W  2.0  1.0
# 4  2023-09-16  21:00  La Liga   Matchweek 5  Sat  Home      W  5.0  0.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 48 2022-05-01  21:00  La Liga  Matchweek 34  Sun  Home      W  2.0  1.0
# 49 2022-05-07  21:00  La Liga  Matchweek 35  Sat  Away      W  2.0  1.0
# 50 2022-05-10  21:30  La Liga  Matchweek 36  Tue  Home      W  3.0  1.0
# 51 2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      D  0.0  0.0
# 52 2022-05-22  22:00  La Liga  Matchweek 38  Sun  Home      L  0.0  2.0
#
#       opponent  ...   fk  pk  pkatt  season       team venue_code opp_code
# 0       Getafe  ...  1.0   0      0    2023  Barcelona          0       10  \
# 1        Cádiz  ...  2.0   0      0    2023  Barcelona          1        7
# 2   Villarreal  ...  0.0   0      0    2023  Barcelona          0       23
# 3      Osasuna  ...  0.0   1      1    2023  Barcelona          0       16
# 4        Betis  ...  2.0   0      0    2023  Barcelona          1        5
# ..         ...  ...  ...  ..    ...     ...        ...        ...      ...
# 48    Mallorca  ...  1.0   0      0    2021  Barcelona          1       15
# 49       Betis  ...  0.0   0      0    2021  Barcelona          0        5
# 50  Celta Vigo  ...  1.0   0      0    2021  Barcelona          1        6
# 51      Getafe  ...  1.0   0      0    2021  Barcelona          0       10
# 52  Villarreal  ...  0.0   0      0    2021  Barcelona          1       23
#
#    hour  day_code  target
# 0    21         6       0
# 1    19         6       1
# 2    17         6       1
# 3    21         6       1
# 4    21         5       1
# ..  ...       ...     ...
# 48   21         6       1
# 49   21         5       1
# 50   21         1       1
# 51   19         6       0
# 52   22         6       0
#
# [81 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group= group.sort_values("date")
    rolling_stats= group[cols].rolling(3,closed='left').mean()
    group[new_cols]=rolling_stats
    group= group.dropna(subset=new_cols)
    return group

# %%
cols=["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols=[f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group,cols,new_cols)
# Out:
#          date   time     comp        round  day venue result   gf   ga
# 4  2021-09-20  21:00  La Liga  Matchweek 5  Mon  Home      D  1.0  1.0  \
# 5  2021-09-23  22:00  La Liga  Matchweek 6  Thu  Away      D  0.0  0.0
# 6  2021-09-26  16:15  La Liga  Matchweek 7  Sun  Home      W  3.0  0.0
# 8  2021-10-02  21:00  La Liga  Matchweek 8  Sat  Away      L  0.0  2.0
# 9  2021-10-17  21:00  La Liga  Matchweek 9  Sun  Home      W  3.0  1.0
# ..        ...    ...      ...          ...  ...   ...    ...  ...  ...
# 0  2023-08-13  21:30  La Liga  Matchweek 1  Sun  Away      D  0.0  0.0
# 1  2023-08-20  19:30  La Liga  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2023-08-27  17:30  La Liga  Matchweek 3  Sun  Away      W  4.0  3.0
# 3  2023-09-03  21:00  La Liga  Matchweek 4  Sun  Away      W  2.0  1.0
# 4  2023-09-16  21:00  La Liga  Matchweek 5  Sat  Home      W  5.0  0.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling
# 4           Granada  ...         0       0    2.333333    1.333333   9.666667  \
# 5             Cádiz  ...         3       0    1.333333    1.000000  11.000000
# 6           Levante  ...         6       1    1.000000    0.666667  10.000000
# 8   Atlético Madrid  ...         5       0    1.333333    0.333333  14.000000
# 9          Valencia  ...         6       1    1.000000    0.666667  11.333333
# ..              ...  ...       ...     ...         ...         ...        ...
# 0            Getafe  ...         6       0    1.666667    1.666667  17.666667
# 1             Cádiz  ...         6       1    1.333333    0.666667  17.000000
# 2        Villarreal  ...         6       1    1.000000    0.666667  15.666667
# 3           Osasuna  ...         6       1    2.000000    1.000000  19.666667
# 4             Betis  ...         5       1    2.666667    1.333333  17.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     4.666667    14.900000   0.333333    0.000000       0.000000
# 5     4.000000    15.600000   0.666667    0.000000       0.000000
# 6     3.666667    16.066667   0.666667    0.000000       0.000000
# 8     6.333333    16.633333   0.666667    0.333333       0.333333
# 9     5.000000    18.733333   1.000000    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 0     5.333333    16.566667   1.333333    0.000000       0.000000
# 1     4.333333    17.733333   1.333333    0.000000       0.000000
# 2     5.000000    17.300000   1.000000    0.000000       0.000000
# 3     8.000000    17.400000   1.000000    0.000000       0.000000
# 4     8.000000    15.966667   0.666667    0.333333       0.333333
#
# [78 rows x 40 columns]

# %%
matches_rolling=matches.groupby("team").apply(lambda x: rolling_averages(x,cols,new_cols))

# %%
matches_rolling
# Out:
#                    date   time     comp        round  day venue result   gf
# team
# Alaves     3 2021-09-18  21:00  La Liga  Matchweek 5  Sat  Home      L  0.0  \
#            4 2021-09-22  19:30  La Liga  Matchweek 6  Wed  Away      L  0.0
#            5 2021-09-25  14:00  La Liga  Matchweek 7  Sat  Home      W  1.0
#            6 2021-10-01  21:00  La Liga  Matchweek 8  Fri  Away      L  0.0
#            7 2021-10-18  19:00  La Liga  Matchweek 9  Mon  Home      L  0.0
# ...                 ...    ...      ...          ...  ...   ...    ...  ...
# Villarreal 0 2023-08-13  19:30  La Liga  Matchweek 1  Sun  Home      L  1.0
#            1 2023-08-18  19:30  La Liga  Matchweek 2  Fri  Away      W  1.0
#            2 2023-08-27  17:30  La Liga  Matchweek 3  Sun  Home      L  3.0
#            3 2023-09-01  19:30  La Liga  Matchweek 4  Fri  Away      L  1.0
#            4 2023-09-17  16:15  La Liga  Matchweek 5  Sun  Home      W  2.0
#
#                ga         opponent  ...  day_code  target  gf_rolling
# team                                ...
# Alaves     3  2.0          Osasuna  ...         5       0    0.333333  \
#            4  1.0         Espanyol  ...         2       0    0.000000
#            5  0.0  Atlético Madrid  ...         5       1    0.000000
#            6  1.0    Athletic Club  ...         4       0    0.333333
#            7  1.0            Betis  ...         0       0    0.333333
# ...           ...              ...  ...       ...     ...         ...
# Villarreal 0  2.0            Betis  ...         6       0    1.666667
#            1  0.0         Mallorca  ...         4       1    1.333333
#            2  4.0        Barcelona  ...         6       0    1.333333
#            3  3.0            Cádiz  ...         4       0    1.666667
#            4  1.0          Almería  ...         6       1    1.666667
#
#               ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling
# team
# Alaves     3    2.666667   9.333333    3.000000    17.633333   0.666667  \
#            4    2.000000   8.666667    3.000000    19.033333   0.333333
#            5    2.000000   8.000000    2.333333    19.066667   0.333333
#            6    1.000000   7.333333    2.000000    17.800000   0.000000
#            7    0.666667  10.333333    2.666667    15.066667   0.000000
# ...                  ...        ...         ...          ...        ...
# Villarreal 0    1.333333  14.000000    5.333333    19.766667   2.000000
#            1    2.000000  15.666667    4.666667    18.633333   1.000000
#            2    1.333333  18.333333    5.000000    17.733333   1.000000
#            3    2.000000  15.333333    4.666667    16.033333   0.333333
#            4    2.333333  11.666667    4.000000    17.100000   0.333333
#
#               pk_rolling  pkatt_rolling
# team
# Alaves     3    0.333333       0.333333
#            4    0.000000       0.000000
#            5    0.000000       0.000000
#            6    0.000000       0.000000
#            7    0.000000       0.000000
# ...                  ...            ...
# Villarreal 0    0.000000       0.000000
#            1    0.000000       0.000000
#            2    0.000000       0.000000
#            3    0.000000       0.000000
#            4    0.000000       0.000000
#
# [1543 rows x 40 columns]

# %%
matches_rolling=matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time     comp        round  day venue result   gf   ga
# 3  2021-09-18  21:00  La Liga  Matchweek 5  Sat  Home      L  0.0  2.0  \
# 4  2021-09-22  19:30  La Liga  Matchweek 6  Wed  Away      L  0.0  1.0
# 5  2021-09-25  14:00  La Liga  Matchweek 7  Sat  Home      W  1.0  0.0
# 6  2021-10-01  21:00  La Liga  Matchweek 8  Fri  Away      L  0.0  1.0
# 7  2021-10-18  19:00  La Liga  Matchweek 9  Mon  Home      L  0.0  1.0
# ..        ...    ...      ...          ...  ...   ...    ...  ...  ...
# 0  2023-08-13  19:30  La Liga  Matchweek 1  Sun  Home      L  1.0  2.0
# 1  2023-08-18  19:30  La Liga  Matchweek 2  Fri  Away      W  1.0  0.0
# 2  2023-08-27  17:30  La Liga  Matchweek 3  Sun  Home      L  3.0  4.0
# 3  2023-09-01  19:30  La Liga  Matchweek 4  Fri  Away      L  1.0  3.0
# 4  2023-09-17  16:15  La Liga  Matchweek 5  Sun  Home      W  2.0  1.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling
# 3           Osasuna  ...         5       0    0.333333    2.666667   9.333333  \
# 4          Espanyol  ...         2       0    0.000000    2.000000   8.666667
# 5   Atlético Madrid  ...         5       1    0.000000    2.000000   8.000000
# 6     Athletic Club  ...         4       0    0.333333    1.000000   7.333333
# 7             Betis  ...         0       0    0.333333    0.666667  10.333333
# ..              ...  ...       ...     ...         ...         ...        ...
# 0             Betis  ...         6       0    1.666667    1.333333  14.000000
# 1          Mallorca  ...         4       1    1.333333    2.000000  15.666667
# 2         Barcelona  ...         6       0    1.333333    1.333333  18.333333
# 3             Cádiz  ...         4       0    1.666667    2.000000  15.333333
# 4           Almería  ...         6       1    1.666667    2.333333  11.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 3     3.000000    17.633333   0.666667    0.333333       0.333333
# 4     3.000000    19.033333   0.333333    0.000000       0.000000
# 5     2.333333    19.066667   0.333333    0.000000       0.000000
# 6     2.000000    17.800000   0.000000    0.000000       0.000000
# 7     2.666667    15.066667   0.000000    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 0     5.333333    19.766667   2.000000    0.000000       0.000000
# 1     4.666667    18.633333   1.000000    0.000000       0.000000
# 2     5.000000    17.733333   1.000000    0.000000       0.000000
# 3     4.666667    16.033333   0.333333    0.000000       0.000000
# 4     4.000000    17.100000   0.333333    0.000000       0.000000
#
# [1543 rows x 40 columns]

# %%
matches_rolling.index=range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time     comp        round  day venue result   gf   ga
# 0    2021-09-18  21:00  La Liga  Matchweek 5  Sat  Home      L  0.0  2.0  \
# 1    2021-09-22  19:30  La Liga  Matchweek 6  Wed  Away      L  0.0  1.0
# 2    2021-09-25  14:00  La Liga  Matchweek 7  Sat  Home      W  1.0  0.0
# 3    2021-10-01  21:00  La Liga  Matchweek 8  Fri  Away      L  0.0  1.0
# 4    2021-10-18  19:00  La Liga  Matchweek 9  Mon  Home      L  0.0  1.0
# ...         ...    ...      ...          ...  ...   ...    ...  ...  ...
# 1538 2023-08-13  19:30  La Liga  Matchweek 1  Sun  Home      L  1.0  2.0
# 1539 2023-08-18  19:30  La Liga  Matchweek 2  Fri  Away      W  1.0  0.0
# 1540 2023-08-27  17:30  La Liga  Matchweek 3  Sun  Home      L  3.0  4.0
# 1541 2023-09-01  19:30  La Liga  Matchweek 4  Fri  Away      L  1.0  3.0
# 1542 2023-09-17  16:15  La Liga  Matchweek 5  Sun  Home      W  2.0  1.0
#
#              opponent  ...  day_code  target  gf_rolling  ga_rolling
# 0             Osasuna  ...         5       0    0.333333    2.666667  \
# 1            Espanyol  ...         2       0    0.000000    2.000000
# 2     Atlético Madrid  ...         5       1    0.000000    2.000000
# 3       Athletic Club  ...         4       0    0.333333    1.000000
# 4               Betis  ...         0       0    0.333333    0.666667
# ...               ...  ...       ...     ...         ...         ...
# 1538            Betis  ...         6       0    1.666667    1.333333
# 1539         Mallorca  ...         4       1    1.333333    2.000000
# 1540        Barcelona  ...         6       0    1.333333    1.333333
# 1541            Cádiz  ...         4       0    1.666667    2.000000
# 1542          Almería  ...         6       1    1.666667    2.333333
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.333333    3.000000    17.633333   0.666667    0.333333       0.333333
# 1      8.666667    3.000000    19.033333   0.333333    0.000000       0.000000
# 2      8.000000    2.333333    19.066667   0.333333    0.000000       0.000000
# 3      7.333333    2.000000    17.800000   0.000000    0.000000       0.000000
# 4     10.333333    2.666667    15.066667   0.000000    0.000000       0.000000
# ...         ...         ...          ...        ...         ...            ...
# 1538  14.000000    5.333333    19.766667   2.000000    0.000000       0.000000
# 1539  15.666667    4.666667    18.633333   1.000000    0.000000       0.000000
# 1540  18.333333    5.000000    17.733333   1.000000    0.000000       0.000000
# 1541  15.333333    4.666667    16.033333   0.333333    0.000000       0.000000
# 1542  11.666667    4.000000    17.100000   0.333333    0.000000       0.000000
#
# [1543 rows x 40 columns]

# %%
def make_predictions(data,predictions):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = ps(test["target"], preds)
    return combined, precision

# %%
combined, precision= make_predictions(matches_rolling, predictors+new_cols)

# %%
precision
# Out:
# 0.5555555555555556

# %%
combined
# Out:
#       actual  predicted
# 35         0          1
# 36         1          0
# 37         0          1
# 38         1          0
# 39         0          0
# ...      ...        ...
# 1538       0          0
# 1539       1          0
# 1540       0          0
# 1541       0          0
# 1542       1          1
#
# [555 rows x 2 columns]

# %%
combined=combined.merge(matches_rolling[["date","team","opponent","result"]], left_index=True, right_index=True)

# %%
combined["opponent"].head(25)
# Out:
# 35              Cádiz
# 36            Sevilla
# 37             Getafe
# 38           Valencia
# 39     Rayo Vallecano
# 52      Real Sociedad
# 53    Atlético Madrid
# 54           Valencia
# 55           Espanyol
# 56     Rayo Vallecano
# 57              Betis
# 58             Girona
# 59          Barcelona
# 60         Villarreal
# 61            Sevilla
# 62              Cádiz
# 63         Celta Vigo
# 64           Valencia
# 65    Atlético Madrid
# 66      Athletic Club
# 67             Getafe
# 68        Real Madrid
# 69              Elche
# 70            Osasuna
# 71           Mallorca
# Name: opponent, dtype: object

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {  "Real Betis": "Betis"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"]= combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date        team        opponent result
# 35         0          1 2023-08-14      Alaves           Cádiz      L  \
# 36         1          0 2023-08-21      Alaves         Sevilla      W
# 37         0          1 2023-08-28      Alaves          Getafe      L
# 38         1          0 2023-09-02      Alaves        Valencia      W
# 39         0          0 2023-09-15      Alaves  Rayo Vallecano      L
# ...      ...        ...        ...         ...             ...    ...
# 1538       0          0 2023-08-13  Villarreal           Betis      L
# 1539       1          0 2023-08-18  Villarreal        Mallorca      W
# 1540       0          0 2023-08-27  Villarreal       Barcelona      L
# 1541       0          0 2023-09-01  Villarreal           Cádiz      L
# 1542       1          1 2023-09-17  Villarreal         Almería      W
#
#         new_team
# 35        Alaves
# 36        Alaves
# 37        Alaves
# 38        Alaves
# 39        Alaves
# ...          ...
# 1538  Villarreal
# 1539  Villarreal
# 1540  Villarreal
# 1541  Villarreal
# 1542  Villarreal
#
# [555 rows x 7 columns]

# %%
merged= combined.merge(combined,left_on=["date","new_team"], right_on=["date","opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date         team_x     opponent_x result_x
# 0           0            0 2023-01-09  Athletic Club        Osasuna        D  \
# 1           0            0 2023-01-14  Athletic Club  Real Sociedad        L
# 2           0            0 2023-01-22  Athletic Club    Real Madrid        L
# 3           0            0 2023-01-29  Athletic Club     Celta Vigo        L
# 4           1            0 2023-02-03  Athletic Club          Cádiz        W
# ..        ...          ...        ...            ...            ...      ...
# 459         0            0 2023-08-13     Villarreal          Betis        L
# 460         1            0 2023-08-18     Villarreal       Mallorca        W
# 461         0            0 2023-08-27     Villarreal      Barcelona        L
# 462         0            0 2023-09-01     Villarreal          Cádiz        L
# 463         1            1 2023-09-17     Villarreal        Almería        W
#
#         new_team_x  actual_y  predicted_y         team_y     opponent_y
# 0    Athletic Club         0            0        Osasuna  Athletic Club  \
# 1    Athletic Club         1            1  Real Sociedad  Athletic Club
# 2    Athletic Club         1            0    Real Madrid  Athletic Club
# 3    Athletic Club         1            0     Celta Vigo  Athletic Club
# 4    Athletic Club         0            0          Cadiz  Athletic Club
# ..             ...       ...          ...            ...            ...
# 459     Villarreal         1            0     Real Betis     Villarreal
# 460     Villarreal         0            0       Mallorca     Villarreal
# 461     Villarreal         1            0      Barcelona     Villarreal
# 462     Villarreal         1            0          Cadiz     Villarreal
# 463     Villarreal         0            0        Almeria     Villarreal
#
#     result_y     new_team_y
# 0          D        Osasuna
# 1          W  Real Sociedad
# 2          W    Real Madrid
# 3          W     Celta Vigo
# 4          L          Cadiz
# ..       ...            ...
# 459        W          Betis
# 460        L       Mallorca
# 461        W      Barcelona
# 462        W          Cadiz
# 463        L        Almeria
#
# [464 rows x 13 columns]

# %%
merged[(merged["predicted_x"]==1)& (merged["predicted_y"]==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    55
# 0    39
# Name: count, dtype: int64

# %% [raw]
# 55/39

# %%
39/55
# Out:
# 0.7090909090909091
