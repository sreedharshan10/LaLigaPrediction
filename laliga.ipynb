# %%
import requests

# %%
standings_url="https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
data = requests.get(standings_url)

# %%
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202309071" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertB
# ...

# %%
from bs4 import BeautifulSoup as Bs

# %%
soup=Bs(data.text)

# %%
standings_table=soup.select('table.stats_table')[0]

# %%
links=standings_table.find_all('a')
#to find all the anchor tags of teams we use this command

# %%
links=[l.get("href") for l in links]

# %%
links=[l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/53a2f082/Real-Madrid-Stats',
#  '/en/squads/206d90db/Barcelona-Stats',
#  '/en/squads/9024a00a/Girona-Stats',
#  '/en/squads/2b390eca/Athletic-Club-Stats',
#  '/en/squads/dcc91a7b/Valencia-Stats',
#  '/en/squads/98e8af82/Rayo-Vallecano-Stats',
#  '/en/squads/db3b9613/Atletico-Madrid-Stats',
#  '/en/squads/7848bd64/Getafe-Stats',
#  '/en/squads/ee7c297c/Cadiz-Stats',
#  '/en/squads/fc536746/Real-Betis-Stats',
#  '/en/squads/e31d1cd9/Real-Sociedad-Stats',
#  '/en/squads/03c57e2b/Osasuna-Stats',
#  '/en/squads/2a8183b3/Villarreal-Stats',
#  '/en/squads/8d6fd021/Alaves-Stats',
#  '/en/squads/2aa12281/Mallorca-Stats',
#  '/en/squads/f25da7fb/Celta-Vigo-Stats',
#  '/en/squads/ad2be733/Sevilla-Stats',
#  '/en/squads/a0435291/Granada-Stats',
#  '/en/squads/0049d422/Las-Palmas-Stats',
#  '/en/squads/78ecf4bb/Almeria-Stats']

# %%
team_urls=[f"https://fbref.com{l}" for l in links]
#to access the urls we use this prefix

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/206d90db/Barcelona-Stats',
#  'https://fbref.com/en/squads/9024a00a/Girona-Stats',
#  'https://fbref.com/en/squads/2b390eca/Athletic-Club-Stats',
#  'https://fbref.com/en/squads/dcc91a7b/Valencia-Stats',
#  'https://fbref.com/en/squads/98e8af82/Rayo-Vallecano-Stats',
#  'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/7848bd64/Getafe-Stats',
#  'https://fbref.com/en/squads/ee7c297c/Cadiz-Stats',
#  'https://fbref.com/en/squads/fc536746/Real-Betis-Stats',
#  'https://fbref.com/en/squads/e31d1cd9/Real-Sociedad-Stats',
#  'https://fbref.com/en/squads/03c57e2b/Osasuna-Stats',
#  'https://fbref.com/en/squads/2a8183b3/Villarreal-Stats',
#  'https://fbref.com/en/squads/8d6fd021/Alaves-Stats',
#  'https://fbref.com/en/squads/2aa12281/Mallorca-Stats',
#  'https://fbref.com/en/squads/f25da7fb/Celta-Vigo-Stats',
# ...

# %%
team_url=team_urls[1]

# %%
data=requests.get(team_url)

# %%
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202309071" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertB
# ...

# %%
import pandas as pd
matches = pd.read_html(data.text,match="Scores & Fixtures")
#to get the scores and fixtures as a pandas data frame we use this command

# %%
matches
# Out:
# [          Date   Time          Comp         Round  Day Venue Result   GF   GA
#  0   2023-08-13  21:30       La Liga   Matchweek 1  Sun  Away      D  0.0  0.0  \
#  1   2023-08-20  19:30       La Liga   Matchweek 2  Sun  Home      W  2.0  0.0
#  2   2023-08-27  17:30       La Liga   Matchweek 3  Sun  Away      W  4.0  3.0
#  3   2023-09-03  21:00       La Liga   Matchweek 4  Sun  Away      W  2.0  1.0
#  4   2023-09-16  21:00       La Liga   Matchweek 5  Sat  Home      W  5.0  0.0
#  5   2023-09-19  21:00  Champions Lg   Group stage  Tue  Home      W  5.0  0.0
#  6   2023-09-23  18:30       La Liga   Matchweek 6  Sat  Home    NaN  NaN  NaN
#  7   2023-09-26  21:30       La Liga   Matchweek 7  Tue  Away    NaN  NaN  NaN
#  8   2023-09-29  21:00       La Liga   Matchweek 8  Fri  Home    NaN  NaN  NaN
#  9   2023-10-04  20:00  Champions Lg   Group stage  Wed  Away    NaN  NaN  NaN
#  10  2023-10-08    NaN       La Liga   Matchweek 9  Sun  Away    NaN  NaN  NaN
# ...

# %% [markdown]
# matches[0]

# %%
matches[0].head()
#since it is a list we use this to display as pd dataframe
# Out:
#          Date   Time     Comp        Round  Day Venue Result   GF   GA
# 0  2023-08-13  21:30  La Liga  Matchweek 1  Sun  Away      D  0.0  0.0  \
# 1  2023-08-20  19:30  La Liga  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2023-08-27  17:30  La Liga  Matchweek 3  Sun  Away      W  4.0  3.0
# 3  2023-09-03  21:00  La Liga  Matchweek 4  Sun  Away      W  2.0  1.0
# 4  2023-09-16  21:00  La Liga  Matchweek 5  Sat  Home      W  5.0  0.0
#
#      Opponent   xG  xGA  Poss  Attendance                Captain Formation
# 0      Getafe  1.4  0.6  74.0     13410.0  Marc-André ter Stegen   4-2-3-1  \
# 1       Cádiz  3.4  1.1  74.0     39603.0  Marc-André ter Stegen     3-4-3
# 2  Villarreal  3.1  1.9  60.0     21679.0          Sergi Roberto     4-3-3
# 3     Osasuna  2.0  0.8  69.0     21966.0          Sergi Roberto     4-3-3
# 4       Betis  2.4  0.8  65.0     45055.0  Marc-André ter Stegen     4-3-3
#
#                     Referee  Match Report  Notes
# ...

# %%
#to get the shooting stats and the other stats we have to get the urls of other pages using the same beautiful soup library
soup= Bs(data.text)

# %%
links=soup.find_all('a')

# %%
links=[l.get("href") for l in links]

# %%
links=[l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/206d90db/2023-2024/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2023-2024/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2023-2024/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2023-2024/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions']

# %%
data= requests.get(f"https://fbref.com{links[0]}")

# %%
shooting=pd.read_html(data.text, match='Shooting')[0]

# %%
shooting.head()
# Out:
#   For Barcelona
#            Date   Time     Comp        Round  Day Venue Result GF GA
# 0    2023-08-13  21:30  La Liga  Matchweek 1  Sun  Away      D  0  0  \
# 1    2023-08-20  19:30  La Liga  Matchweek 2  Sun  Home      W  2  0
# 2    2023-08-27  17:30  La Liga  Matchweek 3  Sun  Away      W  4  3
# 3    2023-09-03  21:00  La Liga  Matchweek 4  Sun  Away      W  2  1
# 4    2023-09-16  21:00  La Liga  Matchweek 5  Sat  Home      W  5  0
#
#                ... Standard             Expected
#      Opponent  ...     Dist FK PK PKatt       xG npxG npxG/Sh G-xG np:G-xG
# 0      Getafe  ...     19.9  1  0     0      1.4  1.4    0.11 -1.4    -1.4  \
# 1       Cádiz  ...     15.5  2  0     0      3.4  3.4    0.15 -1.4    -1.4
# 2  Villarreal  ...     16.8  0  0     0      3.1  3.1    0.15  0.9     0.9
# 3     Osasuna  ...     15.6  0  1     1      2.0  1.2    0.16  0.0    -0.2
# 4       Betis  ...     18.7  2  0     0      2.4  2.4    0.14  2.6     2.6
#
#   Unnamed: 25_level_0
# ...

# %%
shooting.columns=shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result  GF  GA
# 0  2023-08-13  21:30  La Liga  Matchweek 1  Sun  Away      D   0   0  \
# 1  2023-08-20  19:30  La Liga  Matchweek 2  Sun  Home      W   2   0
# 2  2023-08-27  17:30  La Liga  Matchweek 3  Sun  Away      W   4   3
# 3  2023-09-03  21:00  La Liga  Matchweek 4  Sun  Away      W   2   1
# 4  2023-09-16  21:00  La Liga  Matchweek 5  Sat  Home      W   5   0
#
#      Opponent  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0      Getafe  ...  19.9   1   0      0  1.4   1.4     0.11  -1.4     -1.4  \
# 1       Cádiz  ...  15.5   2   0      0  3.4   3.4     0.15  -1.4     -1.4
# 2  Villarreal  ...  16.8   0   0      0  3.1   3.1     0.15   0.9      0.9
# 3     Osasuna  ...  15.6   0   1      1  2.0   1.2     0.16   0.0     -0.2
# 4       Betis  ...  18.7   2   0      0  2.4   2.4     0.14   2.6      2.6
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3  Match Report
# ...

# %%
team_data=matches[0].merge(shooting[["Date","Sh","SoT","Dist","FK","PK","PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result   GF   GA
# 0  2023-08-13  21:30  La Liga  Matchweek 1  Sun  Away      D  0.0  0.0  \
# 1  2023-08-20  19:30  La Liga  Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2023-08-27  17:30  La Liga  Matchweek 3  Sun  Away      W  4.0  3.0
# 3  2023-09-03  21:00  La Liga  Matchweek 4  Sun  Away      W  2.0  1.0
# 4  2023-09-16  21:00  La Liga  Matchweek 5  Sat  Home      W  5.0  0.0
#
#      Opponent  ...  Formation                   Referee  Match Report  Notes
# 0      Getafe  ...    4-2-3-1                César Soto  Match Report    NaN  \
# 1       Cádiz  ...      3-4-3           Alejandro Muñíz  Match Report    NaN
# 2  Villarreal  ...      4-3-3       Alejandro Hernández  Match Report    NaN
# 3     Osasuna  ...      4-3-3  Miguel Ángel Ortiz Arias  Match Report    NaN
# 4       Betis  ...      4-3-3              José Sánchez  Match Report    NaN
#
#    Sh SoT  Dist FK  PK  PKatt
# 0  14   3  19.9  1   0      0
# ...

# %%
years = list(range(2023,2020,-1))

# %%
years
# Out:
# [2023, 2022, 2021]

# %%
all_matches=[]

# %%
standings_url="https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = Bs(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = Bs(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "La Liga"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
match_df=pd.concat(all_matches)

# %%
match_df.columns=[c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matches.csv")

# %%
match_df
# Out:
#           date   time     comp         round  day venue result   gf   ga
# 0   2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0  \
# 1   2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2   2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3   2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4   2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35  2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W    2    1
# 36  2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L    0    4
# 37  2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W    2    1
# 38  2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L    1    3
# 39  2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L    0    1
#
#          opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt
# ...
